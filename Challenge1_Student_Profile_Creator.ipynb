# %% [markdown]
# <a href="https://colab.research.google.com/github/umasankari11/Python-Coding-Challenges/blob/main/Challenge1_Student_Profile_Creator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Student Profile Creator

# Creating variables
student_name = "Umasankari"
student_age = 15
favourite_subjects = ["Math", "Science", "English"]

# Displaying student information
print("----- Student Profile -----")
print(f"Name: {student_name}")
print(f"Age: {student_age}")
print("Favourite Subjects:", favourite_subjects)

# Updating favourite subjects
favourite_subjects.append("Computer Science")

# Displaying updated subjects
print("\n----- Updated Subjects -----")
print("Updated Favourite Subjects:", favourite_subjects)
# Out:
# ----- Student Profile -----
# Name: Umasankari
# Age: 15
# Favourite Subjects: ['Math', 'Science', 'English']
#
# ----- Updated Subjects -----
# Updated Favourite Subjects: ['Math', 'Science', 'English', 'Computer Science']
